# %% [markdown]
# # Annual Housing Development Statistics
#
# Comparing the annual growth rate of completed development projects for single and multi-family unit homes dating back to 1974. The attributes looked at in this analysis are based on the available data.
#
# Those are:
# 1. single-family built (owner) or if they are single-family contractor built
# 2. built for rent or for sale
# 3. unit volume segments
